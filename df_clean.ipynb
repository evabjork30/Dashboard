# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# %%
df = pd.read_excel('Grades Dataset FINAL.xlsx')
df
# Out:
#         StudentID  RegistrationYear Gender  BirthYear         Origin  \
# 0             302              1988   Kona     1954.0        Iceland
# 1             302              1988   Kona     1954.0        Iceland
# 2             302              1988   Kona     1954.0        Iceland
# 3             304              1991   Kona     1964.0        Iceland
# 4             304              1991   Kona     1964.0        Iceland
# ...           ...               ...    ...        ...            ...
# 112949     130962              2022   Karl     2002.0  South America
# 112950     130963              2022   Karl     2002.0  South America
# 112951     130964              2022   Karl     2002.0  South America
# 112952     130965              2022   Karl     2002.0  South America
# 112953     130966              2022   Karl     2002.0  South America
#
#                 Department        Major_Type  \
# 0       Tölvunarfræðideild  Bachelors Degree
# ...

# %%
df['Grade'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Grade'] = df['Grade'].astype(str).str.replace(',', '.').astype(float)

# %%
df.nlargest(5, 'Grade')
# Out:
#        StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 90934      97988              2018   Kona     1999.0  Iceland
# 341          580              1995   Kona     1975.0  Iceland
# 20           314              1998   Karl     1978.0  Iceland
# 46           334              2000   Karl     1973.0  Iceland
# 151          418              1998   Karl     1968.0  Iceland
#
#                Department        Major_Type                  Major  MajorID  \
# 90934       Sálfræðideild  Bachelors Degree         BSc í sálfræði      267
# 341    Tölvunarfræðideild  Bachelors Degree  Diplóma í kerfisfræði        3
# 20     Tölvunarfræðideild  Bachelors Degree    BSc í tölvunarfræði       12
# 46     Tölvunarfræðideild  Bachelors Degree    BSc í tölvunarfræði       12
# 151    Tölvunarfræðideild  Bachelors Degree    BSc í tölvunarfræði       12
#
#       Reg_Status  Semester  Credits  Grade
# 90934  Graduated     20193     32.0   30.0
# 341    Graduated     19952     30.0   25.0
# ...

# %%
df.nsmallest(5, 'Grade')
# Out:
#        StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 200          466              1994   Karl     1974.0  Iceland
# 56079      60590              2011   Karl     1977.0  Iceland
# 23           314              1998   Karl     1978.0  Iceland
# 106          388              1988   Karl     1965.0  Iceland
# 347          584              1995   Karl     1972.0  Iceland
#
#                Department        Major_Type                  Major  MajorID  \
# 200    Tölvunarfræðideild  Bachelors Degree  Diplóma í kerfisfræði        3
# 56079     Tæknifræðideild  Bachelors Degree  Diplóma í véliðnfræði       71
# 23     Tölvunarfræðideild  Bachelors Degree    BSc í tölvunarfræði       12
# 106    Tölvunarfræðideild  Bachelors Degree            Kerfisfræði        1
# 347    Tölvunarfræðideild  Bachelors Degree  Diplóma í kerfisfræði        3
#
#       Reg_Status  Semester  Credits  Grade
# 200    Graduated     19942     30.0  -8.15
# 56079  Graduated     20043     18.0   2.50
# ...

# %%
df.drop(df[df['Grade'] > 10].index, inplace=True)
df.nlargest(5, 'Grade')
# Out:
#       StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 46          334              2000   Karl     1973.0  Iceland
# 151         418              1998   Karl     1968.0  Iceland
# 3548       3076              2000   Karl     1975.0  Iceland
# 3555       3076              2000   Karl     1975.0  Iceland
# 6734       5010              2001   Kona     1974.0  Iceland
#
#                        Department        Major_Type  \
# 46             Tölvunarfræðideild  Bachelors Degree
# 151            Tölvunarfræðideild  Bachelors Degree
# 3548           Tölvunarfræðideild  Bachelors Degree
# 3555           Tölvunarfræðideild  Bachelors Degree
# 6734  Viðskipta- og hagfræðideild  Bachelors Degree
#
#                            Major  MajorID Reg_Status  Semester  Credits  Grade
# 46           BSc í tölvunarfræði       12  Graduated     20012      6.0   10.0
# 151          BSc í tölvunarfræði       12  Graduated     19992      6.0   10.0
# ...

# %%
print(list(df.columns))
# Out:
# ['StudentID', 'RegistrationYear', 'Gender', 'BirthYear', 'Origin', 'Department', 'Major_Type', 'Major', 'MajorID', 'Reg_Status', 'Semester', 'Credits', 'Grade']

# %%
df.nlargest(10, 'BirthYear')
# Out:
#         StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 73288       79476              2015   Karl     2016.0   Europe
# 73289       79476              2015   Karl     2016.0   Europe
# 73290       79476              2015   Karl     2016.0   Europe
# 73291       79476              2015   Karl     2016.0   Europe
# 70360       75744              2014   Kona     2015.0   Europe
# 70361       75744              2014   Kona     2015.0   Europe
# 70362       75744              2014   Kona     2015.0   Europe
# 70363       75744              2014   Kona     2015.0   Europe
# 112419     123478              2023   Kona     2005.0  Iceland
# 112420     123478              2023   Kona     2005.0  Iceland
#
#                Department        Major_Type                            Major  \
# 73288                 MBA    Masters Degree                              MBA
# 73289                 MBA    Masters Degree                              MBA
# ...

# %%
df.drop(df[df['BirthYear'] > 2010].index, inplace=True)
df.nlargest(5, 'BirthYear')
# Out:
#         StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 112419     123478              2023   Kona     2005.0  Iceland
# 112420     123478              2023   Kona     2005.0  Iceland
# 105000     112154              2021   Kona     2004.0  Iceland
# 105001     112154              2021   Kona     2004.0  Iceland
# 105002     112154              2021   Kona     2004.0  Iceland
#
#                Department        Major_Type                            Major  \
# 112419  Íþróttafræðideild  Bachelors Degree  Diplóma í styrk- og þrekþjálfun
# 112420  Íþróttafræðideild  Bachelors Degree  Diplóma í styrk- og þrekþjálfun
# 105000     Verkfræðideild  Bachelors Degree          BSc í rekstrarverkfræði
# 105001     Verkfræðideild  Bachelors Degree          BSc í rekstrarverkfræði
# 105002     Verkfræðideild  Bachelors Degree          BSc í rekstrarverkfræði
#
#         MajorID Reg_Status  Semester  Credits  Grade
# 112419      600  Graduated     20241     30.0   7.60
# ...

# %%
df.nsmallest(5, 'BirthYear')
# Out:
#        StudentID  RegistrationYear Gender  BirthYear         Origin  \
# 66833      72842              2014   Karl     1901.0  North America
# 66834      72842              2014   Karl     1901.0  North America
# 66835      72842              2014   Karl     1901.0  North America
# 66836      72842              2014   Karl     1901.0  North America
# 66837      72848              2014   Karl     1901.0         Europe
#
#            Department      Major_Type  \
# 66833  Verkfræðideild  Masters Degree
# 66834  Verkfræðideild  Masters Degree
# 66835  Verkfræðideild  Masters Degree
# 66836  Verkfræðideild  Masters Degree
# 66837  Verkfræðideild  Masters Degree
#
#                                                Major  MajorID Reg_Status  \
# 66833  MSc í orkuvísindum - Iceland School of Energy      372  Graduated
# 66834  MSc í orkuvísindum - Iceland School of Energy      372  Graduated
# 66835  MSc í orkuvísindum - Iceland School of Energy      372  Graduated
# ...

# %%
count_under_1940 = (df['BirthYear'] < 1940).sum()
print(count_under_1940)
# Out:
# 112

# %%
df.nsmallest(5, 'Semester')
# Out:
#      StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 1          302              1988   Kona     1954.0  Iceland
# 26         318              1988   Karl     1967.0  Iceland
# 135        410              1988   Kona     1966.0  Iceland
# 473        700              1988   Kona     1963.0  Iceland
# 763        960              1988   Kona     1965.0  Iceland
#
#              Department        Major_Type        Major  MajorID Reg_Status  \
# 1    Tölvunarfræðideild  Bachelors Degree  Kerfisfræði        1  Graduated
# 26   Tölvunarfræðideild  Bachelors Degree  Kerfisfræði        1  Graduated
# 135  Tölvunarfræðideild  Bachelors Degree  Kerfisfræði        1  Graduated
# 473  Tölvunarfræðideild  Bachelors Degree  Kerfisfræði        1  Graduated
# 763  Tölvunarfræðideild  Bachelors Degree  Kerfisfræði        1  Graduated
#
#      Semester  Credits  Grade
# 1       19881     30.0   8.82
# 26      19881     30.0   9.34
# 135     19881     30.0   6.79
# ...

# %%
count_under_2005 = (df['Semester'] < 20051).sum()
count_under_2005
# Out:
# np.int64(21877)

# %%
count_over_2005 = (df['Semester'] >= 20051).sum()
count_over_2005
# Out:
# np.int64(91066)

# %%
df.drop(df[df['Semester'] < 20051].index, inplace=True)
df.nsmallest(5, 'Semester')
# Out:
#       StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 3757       3176              2000   Kona     1977.0  Iceland
# 3845       3226              2000   Karl     1980.0  Iceland
# 3877       3238              2000   Kona     1968.0  Iceland
# 4046       3322              2000   Kona     1980.0  Iceland
# 4357       3468              2000   Karl     1980.0  Iceland
#
#                        Department        Major_Type  \
# 3757  Viðskipta- og hagfræðideild  Bachelors Degree
# 3845  Viðskipta- og hagfræðideild  Bachelors Degree
# 3877           Tölvunarfræðideild  Bachelors Degree
# 4046           Tölvunarfræðideild  Bachelors Degree
# 4357  Viðskipta- og hagfræðideild  Bachelors Degree
#
#                                                   Major  MajorID Reg_Status  \
# 3757                               BSc í viðskiptafræði        4  Graduated
# 3845                               BSc í viðskiptafræði        4  Graduated
# ...

# %%
df.nsmallest(5, 'Semester')
# Out:
#       StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 3757       3176              2000   Kona     1977.0  Iceland
# 3845       3226              2000   Karl     1980.0  Iceland
# 3877       3238              2000   Kona     1968.0  Iceland
# 4046       3322              2000   Kona     1980.0  Iceland
# 4357       3468              2000   Karl     1980.0  Iceland
#
#                        Department        Major_Type  \
# 3757  Viðskipta- og hagfræðideild  Bachelors Degree
# 3845  Viðskipta- og hagfræðideild  Bachelors Degree
# 3877           Tölvunarfræðideild  Bachelors Degree
# 4046           Tölvunarfræðideild  Bachelors Degree
# 4357  Viðskipta- og hagfræðideild  Bachelors Degree
#
#                                                   Major  MajorID Reg_Status  \
# 3757                               BSc í viðskiptafræði        4  Graduated
# 3845                               BSc í viðskiptafræði        4  Graduated
# ...

# %%
count_under_1940 = (df['BirthYear'] < 1930).sum()
print(count_under_1940)
# Out:
# 111

# %%
df.drop(df[df['BirthYear'] < 1930].index, inplace=True)
df.nsmallest(5, 'BirthYear')
# Out:
#        StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 31876      32638              2006   Kona     1943.0  Iceland
# 31877      32638              2006   Kona     1943.0  Iceland
# 31878      32638              2006   Kona     1943.0  Iceland
# 31879      32638              2006   Kona     1943.0  Iceland
# 42926      47606              2008   Karl     1946.0  Iceland
#
#                             Department        Major_Type  \
# 31876  Kennslufræði- og lýðheilsudeild  Bachelors Degree
# 31877  Kennslufræði- og lýðheilsudeild  Bachelors Degree
# 31878  Kennslufræði- og lýðheilsudeild  Bachelors Degree
# 31879  Kennslufræði- og lýðheilsudeild  Bachelors Degree
# 42926      Viðskipta- og hagfræðideild    Masters Degree
#
#                                                    Major  MajorID Reg_Status  \
# 31876                            Diplómanám í stærðfræði      234  Graduated
# 31877                            Diplómanám í stærðfræði      234  Graduated
# ...

# %%
df['Credits'] = df['Credits'].astype(str).str.replace(',', '.').astype(float)
df.nlargest(10, 'Credits')
# Out:
#        StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 26642      27922              2005   Kona     1964.0  Iceland
# 30454      30644              2005   Kona     1960.0  Iceland
# 29616      29896              2005   Karl     1973.0  Iceland
# 26452      27618              2005   Karl     1973.0  Iceland
# 26475      27662              2005   Karl     1969.0  Iceland
# 35248      37914              2007   Kona     1984.0  Iceland
# 43615      48488              2008   Karl     1976.0  Iceland
# 57697      63266              2012   Karl     1990.0  Iceland
# 57735      63300              2012   Karl     1990.0  Iceland
# 30478      30668              2005   Kona     1981.0  Iceland
#
#                         Department        Major_Type  \
# 26642               Verkfræðideild  Bachelors Degree
# 30454               Verkfræðideild  Bachelors Degree
# 29616              Tæknifræðideild  Bachelors Degree
# 26452  Viðskipta- og hagfræðideild  Bachelors Degree
# ...

# %%
count = (df['Credits'] > 60).sum()
print(count)
# Out:
# 582

# %%
df.drop(df[df['Credits'] > 60].index, inplace=True)
df.nsmallest(5, 'Credits')
# Out:
#        StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 51894      56764              2010   Karl     1978.0  Iceland
# 16681      15926              2003   Karl     1982.0  Iceland
# 26531      27802              2005   Karl     1966.0  Iceland
# 56958      61820              2012   Kona     1984.0  Iceland
# 68656      74598              2014   Karl     1974.0  Iceland
#
#             Department        Major_Type                        Major  \
# 51894        Lagadeild    Masters Degree                ML í lögfræði
# 16681   Verkfræðideild  Bachelors Degree            Geislafræði B.Sc.
# 26531  Tæknifræðideild  Bachelors Degree    BSc í byggingartæknifræði
# 56958  Tæknifræðideild  Bachelors Degree  Diplóma í byggingariðnfræði
# 68656  Tæknifræðideild  Bachelors Degree    BSc í byggingartæknifræði
#
#        MajorID Reg_Status  Semester  Credits  Grade
# 51894       57  Graduated     20113      1.5    8.0
# 16681      137  Graduated     20061      2.0    7.5
# ...

# %%
df.nsmallest(5, 'RegistrationYear')
# Out:
#        StudentID  RegistrationYear Gender  BirthYear   Origin  \
# 24803      24926              1992   Karl     1958.0  Iceland
# 24805      24926              1992   Karl     1958.0  Iceland
# 24806      24926              1992   Karl     1958.0  Iceland
# 24807      24926              1992   Karl     1958.0  Iceland
# 24808      24926              1992   Karl     1958.0  Iceland
#
#             Department        Major_Type                  Major  MajorID  \
# 24803  Tæknifræðideild  Bachelors Degree  Diplóma í rafiðnfræði       70
# 24805  Tæknifræðideild  Bachelors Degree  Diplóma í rafiðnfræði       70
# 24806  Tæknifræðideild  Bachelors Degree  Diplóma í rafiðnfræði       70
# 24807  Tæknifræðideild  Bachelors Degree  Diplóma í rafiðnfræði       70
# 24808  Tæknifræðideild  Bachelors Degree  Diplóma í rafiðnfræði       70
#
#       Reg_Status  Semester  Credits  Grade
# 24803  Graduated     20071     12.0   8.50
# 24805  Graduated     20051     18.0   7.00
# ...

# %%
df['reg_birth_diff'] = df['RegistrationYear'] - df['BirthYear']

# %%
df.nlargest(5, 'reg_birth_diff')
# Out:
#        StudentID  RegistrationYear Gender  BirthYear   Origin Department  \
# 82664      90370              2017   Karl     1950.0  Iceland  Lagadeild
# 82665      90370              2017   Karl     1950.0  Iceland  Lagadeild
# 82666      90370              2017   Karl     1950.0  Iceland  Lagadeild
# 82667      90370              2017   Karl     1950.0  Iceland  Lagadeild
# 82668      90370              2017   Karl     1950.0  Iceland  Lagadeild
#
#            Major_Type          Major  MajorID Reg_Status  Semester  Credits  \
# 82664  Masters Degree  ML í lögfræði       57  Graduated     20203    15.00
# 82665  Masters Degree  ML í lögfræði       57  Graduated     20173     8.00
# 82666  Masters Degree  ML í lögfræði       57  Graduated     20181    15.00
# 82667  Masters Degree  ML í lögfræði       57  Graduated     20183    22.50
# 82668  Masters Degree  ML í lögfræði       57  Graduated     20191    18.75
#
#        Grade  reg_birth_diff
# 82664   6.00            67.0
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Karl', 'Kona', 'Kynsegin/annað'], dtype=object)

# %%
df['Origin'].unique()
# Out:
# array(['Iceland', 'Europe', 'North America', 'Asia', 'Africa',
#        'South America', 'NoWhereLand', 'Oceania'], dtype=object)

# %%
count = (df['Origin'] == 'NoWhereLand').sum()
print(count)
# Out:
# 1

# %%
df = df[df['Origin'] != 'NoWhereLand']
df
# Out:
#         StudentID  RegistrationYear Gender  BirthYear         Origin  \
# 655           864              1998   Karl     1973.0        Iceland
# 3720         3160              2000   Kona     1973.0        Iceland
# 3757         3176              2000   Kona     1977.0        Iceland
# 3836         3226              2000   Karl     1980.0        Iceland
# 3845         3226              2000   Karl     1980.0        Iceland
# ...           ...               ...    ...        ...            ...
# 112949     130962              2022   Karl     2002.0  South America
# 112950     130963              2022   Karl     2002.0  South America
# 112951     130964              2022   Karl     2002.0  South America
# 112952     130965              2022   Karl     2002.0  South America
# 112953     130966              2022   Karl     2002.0  South America
#
#                          Department        Major_Type  \
# 655              Tölvunarfræðideild  Bachelors Degree
# ...

# %%
df['Department'].unique()
# Out:
# array(['Tölvunarfræðideild', 'Viðskipta- og hagfræðideild', 'Lagadeild',
#        'MBA', 'Verkfræðideild', 'Tæknifræðideild', 'Frumgreinadeild',
#        'Íþróttafræðideild', 'Kennslufræði- og lýðheilsudeild',
#        'Sálfræðideild', 'MPM'], dtype=object)

# %%
df['Major'].unique()
# Out:
# array(['BSc í tölvunarfræði', 'BSc í viðskiptafræði',
#        'BSc í tölvunarfræði með viðskiptafræði sem aukagrein',
#        'BSc í viðskiptafræði með tölvunarfræði sem aukagrein',
#        'Diplóma í kerfisfræði', 'Diplóma í kerfisfræði - HMV',
#        'Diplóma í kerfisfræði - Fjarnám', 'BSc í viðskiptafræði (HMV)',
#        'Diploma - Fjármál og rekstur',
#        'Diploma - Stjórnun og starfsmannamál', 'MBA - Mannauðsstjórnun',
#        'BA í lögfræði', 'BS í tölvunarfræði - Kerfishugbúnaður',
#        'BSc í tölvunarfræði - raunvísindaval', 'MBA',
#        'Diploma - Markaðsfræði og alþjóðaviðsk.', 'MSc í tölvunarfræði',
#        'BSc í viðskiptafræði - áhersla á tungumál',
#        'Meistaranám í fjárfestingarstjórnun', 'Geislafræði B.Sc.',
#        'BSc í byggingartæknifræði/framkvæmda- og lagnasvið',
#        'Tölvu- og upplýsingatæknifræði B.Sc',
#        'Viðskiptafræði, B.Sc., af vörustjórnunarsviði',
#        'Diplóma í véliðnfræði', 'Diplóma í rafiðnfræði',
# ...

# %%
df['Major_Type'].unique()
# Out:
# array(['Bachelors Degree', 'Masters Degree', 'Preliminary Degree'],
#       dtype=object)

# %%
df['Reg_Status'].unique()
# Out:
# array(['Graduated'], dtype=object)

# %%
df.to_excel("df_clean.xlsx", index=False)

# %%
#df['Unnamed: 13'].unique()

# %%
#df = df.drop(columns=['Unnamed: 13'])

# %%
#df.to_excel("df_clean.xlsx", index=False)

# %%
df.isna().sum()
# Out:
# StudentID           0
# RegistrationYear    0
# Gender              0
# BirthYear           4
# Origin              0
# Department          0
# Major_Type          0
# Major               0
# MajorID             0
# Reg_Status          0
# Semester            0
# Credits             0
# Grade               0
# reg_birth_diff      4
# dtype: int64

# %%
df = df.dropna(subset=['BirthYear'])

# %%
df
# Out:
#         StudentID  RegistrationYear Gender  BirthYear         Origin  \
# 655           864              1998   Karl     1973.0        Iceland
# 3720         3160              2000   Kona     1973.0        Iceland
# 3757         3176              2000   Kona     1977.0        Iceland
# 3836         3226              2000   Karl     1980.0        Iceland
# 3845         3226              2000   Karl     1980.0        Iceland
# ...           ...               ...    ...        ...            ...
# 112949     130962              2022   Karl     2002.0  South America
# 112950     130963              2022   Karl     2002.0  South America
# 112951     130964              2022   Karl     2002.0  South America
# 112952     130965              2022   Karl     2002.0  South America
# 112953     130966              2022   Karl     2002.0  South America
#
#                          Department        Major_Type  \
# 655              Tölvunarfræðideild  Bachelors Degree
# ...

# %%
#df.to_excel("df_clean.xlsx", index=False)

# %% [markdown]
# ### Streamlit test

# %%
import streamlit as st
import matplotlib.pyplot as plt

# %%
df['Year'] = (df['Semester'] // 10).astype(int)
#df.loc[:, 'Year'] = (df['Semester'] // 10).astype(int)
grade_trends = df.groupby('Year')['Grade'].mean()

# %matplotlib inline

plt.figure(figsize=(14, 6))
ax = plt.gca()

plt.plot(grade_trends.index, grade_trends.values, marker='o', linestyle='-', color='red')
plt.xlabel('Year', fontsize=12.5)
plt.ylabel('Average Grade', fontsize=12.5)
plt.title('Trend of average grades', fontsize=15, weight='bold')
plt.xticks(sorted(df['Year'].unique())) 
plt.grid(True, linestyle='--', linewidth=0.5, color='gray', alpha=0.35)
plt.savefig("grade_inflation.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/v4/9h6hptfx1fs3td46njzw95080000gn/T/ipykernel_9348/881524651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = (df['Semester'] // 10).astype(int)

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

@st.cache_data  # Cache to improve performance
def load_data():
    df = pd.read_excel("df_clean.xlsx")  # Or pd.read_excel("grades.xlsx")
    df['Year'] = (df['Semester'] // 10).astype(int)
    return df

df = load_data()  # ✅ Load the dataset properly

# ------------------------------
# Streamlit App
# ------------------------------
st.title("📊 Grade Inflation Dashboard")
st.write("This dashboard tracks **grade inflation** by analyzing the trend of average grades per year.")

# Check if the data is loaded
if df.empty:
    st.warning("⚠ No data found! Please check your dataset.")
else:
    # Calculate Grade Trends
    grade_trends = df.groupby('Year')['Grade'].mean()

    # Create a Matplotlib Plot
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(grade_trends.index, grade_trends.values, marker='o', linestyle='-', color='red')
    ax.set_xlabel('Year', fontsize=12.5)
    ax.set_ylabel('Average Grade', fontsize=12.5)
    ax.set_title('Trend of Average Grades', fontsize=15, weight='bold')
    ax.grid(True, linestyle='--', linewidth=0.5, color='gray', alpha=0.35)

    # Display in Streamlit
    st.pyplot(fig)

    # Add Filters (Optional)
    year_range = st.slider("Select Year Range:", 
                           min_value=int(df['Year'].min()), 
                           max_value=int(df['Year'].max()), 
                           value=(int(df['Year'].min()), int(df['Year'].max())))
    
    filtered_data = df[(df['Year'] >= year_range[0]) & (df['Year'] <= year_range[1])]

    # Show Filtered Data
    st.write("### Filtered Data Table")
    st.dataframe(filtered_data)
# Out:
# 2025-02-21 16:52:02.421 No runtime found, using MemoryCacheStorageManager
# 2025-02-21 16:52:02.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-21 16:52:02.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-21 16:52:02.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-21 16:52:02.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-21 16:52:02.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-21 16:52:02.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-21 16:52:02.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
